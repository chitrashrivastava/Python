# %%
import pandas as pd
data=pd.read_csv('diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
mc=data.head(5)
mc
bc= data.tail(5)
bc
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
middle_index = len(data) // 2
start_index = max(0, middle_index - 5)

end_index = min(len(data), middle_index + 5)

middle_data = data[start_index:end_index]
middle_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 379            0       93            100             39       72  43.4
# 380            1      107             72             30       82  30.8
# 381            0      105             68             22        0  20.0
# 382            1      109             60              8      182  25.4
# 383            1       90             62             18       59  25.1
# 384            1      125             70             24      110  24.3
# 385            1      119             54             13       50  22.3
# 386            5      116             74             29        0  32.3
# 387            8      105            100             36        0  43.3
# 388            5      144             82             26      285  32.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 379                     1.021   35        0
# 380                     0.821   24        0
# 381                     0.236   22        0
# ...
